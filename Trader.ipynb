# %%
# Imported Libraries
from ib_async import IB, Stock, MarketOrder

# %%
# Connecting to the API

try:
    ib.disconnect()
except NameError:
    pass

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=11)
print('Connected', ib.isConnected())
print('Account', ib.managedAccounts())

ib.reqMarketDataType(3)

aapl = Stock('AAPL', 'SMART', 'USD')
ib.qualifyContracts(aapl)
ticker = ib.reqMktData(aapl)
ib.sleep(3)
print('AAPL price:', ticker.marketPrice())

# %%
# Collecting the data

# %%
# Cleaning the data

# %%
# Saving the data

# %%
# Training The Model

# %%
# Saving The Model

# %%
# Running The Model

# %%
# Disconnect From API

ib.disconnect()
