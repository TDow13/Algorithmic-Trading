# %%
# Imported Libraries

import nest_asyncio
nest_asyncio.apply()

from ib_async import IB, Stock, MarketOrder

# %%
# Connecting to the API

try:
    ib.disconnect()
except NameError:
    pass

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=11)
print('Connected', ib.isConnected())
print('Account', ib.managedAccounts())
# Out:
# Connected True
# Account ['DUR992754']

# %%
# Collecting the data

# %%
# Cleaning the data

# %%
# Saving the data

# %%
# Training The Model

# %%
# Saving The Model

# %%
# Running The Model

# %%
# Disconnect From API

ib.disconnect()
# Out:
# 'Disconnecting from 127.0.0.1:7497, 118 B sent in 8 messages, 23.9 kB received in 428 messages, session time 406 ms.'
